# %% [markdown]
# This notebook visualises flight data from parquet files to validate the unique flight id assignment scripts.

# %%
from __future__ import annotations

from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.basemap import Basemap

# %%
location_of_flight_parquet_files = "/mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft"

# Get all parquet files in the directory
parquet_files = [f for f in Path(location_of_flight_parquet_files).iterdir() if f.suffix == '.parquet']
print(f"Found {len(parquet_files)} parquet files")
# Out:
# Found 50 parquet files

# %%
# import airport data for plotting
airport_data = pd.read_parquet("../airport_data/airports.parquet")

# %%
def calculate_departure_arrival_airports_completion_percentage(flight_data: pd.DataFrame, flight_ids: list[str]) -> float:
    """Calculate percentage of flights with complete departure and arrival airport information.

    Args:
        flight_data (pd.DataFrame): DataFrame containing flight data.
        flight_ids (list[str]): List of unique flight IDs.

    Returns:
        float: Percentage of flights with complete departure and arrival airport information.
    """
    number_of_flights = len(flight_ids)
    if number_of_flights == 0:
        return "N/A"
    number_of_complete_departure_arrival_pairs = 0
    for flight_id in flight_ids:
        flight = flight_data[flight_data['flight_id'] == flight_id]
        departure_airport = flight['departure_airport_icao'].dropna().iloc[0] if len(flight['departure_airport_icao'].dropna()) > 0 else None
        arrival_airport = flight['arrival_airport_icao'].dropna().iloc[0] if len(flight['arrival_airport_icao'].dropna()) > 0 else None
        boolean_complete = departure_airport is not None and arrival_airport is not None
        number_of_complete_departure_arrival_pairs += int(boolean_complete)

    return (number_of_complete_departure_arrival_pairs / number_of_flights) * 100

def plot_flight_paths(flight_data: pd.DataFrame, flight_ids: list[str], airport_data: pd.DataFrame,) -> None:
    """Plot flight paths from a parquet file on a map with airport markers.

    Args:
        flight_data (pd.DataFrame): DataFrame containing flight data.
        flight_ids (list[str]): List of unique flight IDs.
        airport_data (pd.DataFrame): DataFrame containing airport data.
    """
    plt.figure(figsize=(14, 10))

    # Calculate bounds for all flights and airports
    lat_min = flight_data['latitude'].min() - 1.0
    lat_max = flight_data['latitude'].max() + 1.0
    lon_min = flight_data['longitude'].min() - 1.0
    lon_max = flight_data['longitude'].max() + 1.0

    # Create basemap
    m = Basemap(projection='merc', llcrnrlat=lat_min, urcrnrlat=lat_max,
                llcrnrlon=lon_min, urcrnrlon=lon_max, resolution='i')
    m.drawcoastlines()
    m.drawcountries()
    m.drawmapboundary()
    m.fillcontinents()

     # Plot each flight with a different color
    colors = plt.colormaps['tab20'].resampled(len(flight_ids)).colors

    for idx, flight_id in enumerate(flight_ids):
        flight = flight_data[flight_data["flight_id"] == flight_id]

        # Convert coordinates
        x, y = m(flight['longitude'].to_numpy(), flight['latitude'].to_numpy())

        # Plot the flight path
        m.plot(x, y, marker=None, color=colors[idx], linewidth=2, label=f"Flight {flight_id[-4:]}")

        # Mark first timestep (green triangle)
        m.plot(x[0], y[0], marker='^', color='green', markersize=5, markeredgecolor='black', markeredgewidth=1)

        # Mark last timestep (red square)
        m.plot(x[-1], y[-1], marker='s', color='red', markersize=5, markeredgecolor='black', markeredgewidth=1)

        # Get origin and destination ICAO codes - find first non-null value if exists
        origin_icao = None
        dest_icao = None

        if 'departure_airport_icao' in flight.columns:
            origin_values = flight['departure_airport_icao'].dropna()
            origin_icao = origin_values.iloc[0] if len(origin_values) > 0 else None

        if 'arrival_airport_icao' in flight.columns:
            dest_values = flight['arrival_airport_icao'].dropna()
            dest_icao = dest_values.iloc[0] if len(dest_values) > 0 else None

        # Plot origin airport (skip if None)
        if origin_icao and pd.notna(origin_icao) and origin_icao in airport_data['icao'].to_numpy():
            airport = airport_data[airport_data['icao'] == origin_icao].iloc[0]
            ax, ay = m(airport['lon'], airport['lat'])
            m.plot(ax, ay, marker='x', color=colors[idx], markersize=15, markeredgewidth=2, alpha=0.8)

        # Plot destination airport (skip if None)
        if dest_icao and pd.notna(dest_icao) and dest_icao in airport_data['icao'].to_numpy():
            airport = airport_data[airport_data['icao'] == dest_icao].iloc[0]
            ax, ay = m(airport['lon'], airport['lat'])
            m.plot(ax, ay, marker='x', color=colors[idx], markersize=15, markeredgewidth=2, alpha=0.8)

# %%
# Create output directory if it doesn't exist
output_dir = "flight_sample_plots"
Path(output_dir).mkdir(parents=True, exist_ok=True)

# Process and plot each aircraft file
for parquet_file in parquet_files:
    print(f"\nProcessing {parquet_file}...")

    # Read flight data
    flight_data = pd.read_parquet(f"{parquet_file}")
    flight_ids = flight_data['flight_id'].unique()
    aircraft_icao = parquet_file.stem.replace('aircraft_', '')

    # Check arrival and departure airports for each flight
    percentage_complete = calculate_departure_arrival_airports_completion_percentage(flight_data, flight_ids)

    # Plot all flight paths on a single map with different colors
    plot_flight_paths(flight_data, flight_ids, airport_data)

    # Add legend with statistics
    plt.legend(loc='upper left', fontsize=10, framealpha=0.9)
    plt.title(f"Flight Paths for {aircraft_icao} with Start (▲), End (■), and Airports (x)")
    plt.suptitle(f"Complete Airport Data: {percentage_complete:.2f}%", y=0.92, fontsize=10)

    # Save the figure
    output_path = Path(output_dir) / f"{aircraft_icao}.png"
    plt.savefig(output_path, dpi=150, bbox_inches='tight')
    print(f"  Saved plot to {output_path}")
    plt.close()
# Out:
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_0AC390.parquet...
#   Saved plot to flight_sample_plots/0AC390.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_155C38.parquet...
#   Saved plot to flight_sample_plots/155C38.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_34224F.parquet...
#   Saved plot to flight_sample_plots/34224F.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_3455D8.parquet...
#   Saved plot to flight_sample_plots/3455D8.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_346605.parquet...
#   Saved plot to flight_sample_plots/346605.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_3C5EE4.parquet...
#   Saved plot to flight_sample_plots/3C5EE4.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4853D1.parquet...
#   Saved plot to flight_sample_plots/4853D1.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4A2AAC.parquet...
#   Saved plot to flight_sample_plots/4A2AAC.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4BA915.parquet...
#   Saved plot to flight_sample_plots/4BA915.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4BA9E6.parquet...
#   Saved plot to flight_sample_plots/4BA9E6.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4BB164.parquet...
#   Saved plot to flight_sample_plots/4BB164.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4CA4F2.parquet...
#   Saved plot to flight_sample_plots/4CA4F2.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4CA614.parquet...
#   Saved plot to flight_sample_plots/4CA614.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_4CC57E.parquet...
#   Saved plot to flight_sample_plots/4CC57E.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_702087.parquet...
#   Saved plot to flight_sample_plots/702087.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_74072E.parquet...
#   Saved plot to flight_sample_plots/74072E.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_780417.parquet...
#   Saved plot to flight_sample_plots/780417.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_7805E9.parquet...
#   Saved plot to flight_sample_plots/7805E9.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_7815FF.parquet...
#   Saved plot to flight_sample_plots/7815FF.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_7C432A.parquet...
#   Saved plot to flight_sample_plots/7C432A.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_7C6C25.parquet...
#   Saved plot to flight_sample_plots/7C6C25.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_7C7701.parquet...
#   Saved plot to flight_sample_plots/7C7701.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_80047A.parquet...
#   Saved plot to flight_sample_plots/80047A.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_841024.parquet...
#   Saved plot to flight_sample_plots/841024.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_8880F1.parquet...
#   Saved plot to flight_sample_plots/8880F1.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_8A097B.parquet...
#   Saved plot to flight_sample_plots/8A097B.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A05671.parquet...
#   Saved plot to flight_sample_plots/A05671.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A06A12.parquet...
#   Saved plot to flight_sample_plots/A06A12.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A06D1D.parquet...
#   Saved plot to flight_sample_plots/A06D1D.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A310BB.parquet...
#   Saved plot to flight_sample_plots/A310BB.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A3323D.parquet...
#   Saved plot to flight_sample_plots/A3323D.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A34FE6.parquet...
#   Saved plot to flight_sample_plots/A34FE6.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A3E47F.parquet...
#   Saved plot to flight_sample_plots/A3E47F.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A4BF70.parquet...
#   Saved plot to flight_sample_plots/A4BF70.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A4CD7E.parquet...
#   Saved plot to flight_sample_plots/A4CD7E.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A699D8.parquet...
#   Saved plot to flight_sample_plots/A699D8.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A6AA0A.parquet...
#   Saved plot to flight_sample_plots/A6AA0A.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A6B00E.parquet...
#   Saved plot to flight_sample_plots/A6B00E.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A7F6F5.parquet...
#   Saved plot to flight_sample_plots/A7F6F5.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_A8793D.parquet...
#   Saved plot to flight_sample_plots/A8793D.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_AAA96F.parquet...
#   Saved plot to flight_sample_plots/AAA96F.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_ABDD91.parquet...
#   Saved plot to flight_sample_plots/ABDD91.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_AC3030.parquet...
#   Saved plot to flight_sample_plots/AC3030.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_AC340A.parquet...
#   Saved plot to flight_sample_plots/AC340A.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_AC786A.parquet...
#   Saved plot to flight_sample_plots/AC786A.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_ACCA88.parquet...
#   Saved plot to flight_sample_plots/ACCA88.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_C011B6.parquet...
#   Saved plot to flight_sample_plots/C011B6.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_C01CAE.parquet...
#   Saved plot to flight_sample_plots/C01CAE.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_C0799E.parquet...
#   Saved plot to flight_sample_plots/C0799E.png
#
# Processing /mnt/c/Users/as3091/Documents/sample_aircraft/sample_aircraft/aircraft_C085DF.parquet...
#   Saved plot to flight_sample_plots/C085DF.png
